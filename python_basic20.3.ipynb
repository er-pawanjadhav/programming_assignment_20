# %%
def cone_volumn(r,h):
    r=r*r
    r=r*3.14
    h=h/3
    v=r*h
    return v

radius = int(input("enter the value of radius : "))
height = int(input("enter the value of height : "))

result = cone_volumn(radius,height)
print(f"volumn of cone is : {result}")
# Out:
# enter the value of radius : 2
# enter the value of height : 3
# volumn of cone is : 12.56
