# %%
def num_ret(a):
    b = []
    for i in a:
        if type(i)==int:
            b.append(i)
    return b

a = ["A", 0, "Edabit", 1729, "Python", "1729"]

c =num_ret(a)
print(c)
# Out:
# [0, 1729]
