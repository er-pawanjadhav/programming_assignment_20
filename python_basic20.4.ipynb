# %%
def dots(n):
    n = n*(n+1)
    n=n//2
    return n

n = int(input("enter no of triangle : "))
print(f"no of dots in {5} triangle is {dots(n)}")
# Out:
# enter no of triangle : 215
# no of dots in 5 triangle is 23220
