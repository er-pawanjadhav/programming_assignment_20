# %%
import random

def missing(a,len_b):
    for i in len_b:
        if i not in a:
            return i

a=list(range(1,11))
a.pop(random.randint(1,9))
len_a = len(a) 
len_b = list(range(1,len(a)+2))

print(f"{a} \nmissing no is {missing(a,len_b)}")
# Out:
# [1, 3, 4, 5, 6, 7, 8, 9, 10]
# missing no is 2
