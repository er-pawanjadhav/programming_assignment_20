# %%
def function2(a):
    b = []
    for i in range(len(a)):
        if i ==0:
            b.append(a[i])
        elif i>=1:     
            c=a[i]+i
            b.append(c)
    return b
            
num = [5,4,3,2,1]

print(function2(num))
# Out:
# [5, 5, 5, 5, 5]
